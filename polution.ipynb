# %%
import pandas as pd 
data=pd.read_csv(r"C:\Users\ATHIRA\Desktop\Bangalore_AQI_Dataset.csv")
data
# Out:
#            City      Date  AQI  PM2.5   PM10    NO2    SO2    CO     O3
# 0     Bangalore  01/01/18   68  37.40  73.44  56.44  77.52  0.71  64.60
# 1     Bangalore  02/01/18   76  41.80  82.08  63.08  86.64  0.80  72.20
# 2     Bangalore  03/01/18   70  38.50  75.60  58.10  79.80  0.74  66.50
# 3     Bangalore  04/01/18   78  42.90  84.24  64.74  88.92  0.82  74.10
# 4     Bangalore  05/01/18   82  45.10  88.56  68.06  93.48  0.86  77.90
# ...         ...       ...  ...    ...    ...    ...    ...   ...    ...
# 2551  Bangalore  27/12/24   54  29.70  58.32  44.82  61.56  0.57  51.30
# 2552  Bangalore  28/12/24   57  31.35  61.56  47.31  64.98  0.60  54.15
# 2553  Bangalore  29/12/24   70  38.50  75.60  58.10  79.80  0.74  66.50
# 2554  Bangalore  30/12/24   62  34.10  66.96  51.46  70.68  0.65  58.90
# 2555  Bangalore  31/12/24   65  35.75  70.20  53.95  74.10  0.68  61.75
#
# [2556 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# City     0
# Date     0
# AQI      0
# PM2.5    0
# PM10     0
# NO2      0
# SO2      0
# CO       0
# O3       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# City     0
# Date     0
# AQI      0
# PM2.5    0
# PM10     0
# NO2      0
# SO2      0
# CO       0
# O3       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['AQI	'] = le1.fit_transform(data['AQI'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['PM2.5	'] = le1.fit_transform(data['PM2.5'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['PM10'] = le1.fit_transform(data['PM10'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['NO2'] = le1.fit_transform(data['NO2'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['SO2'] = le1.fit_transform(data['SO2'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['CO'] = le1.fit_transform(data['CO'])

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
data['O3'] = le1.fit_transform(data['O3'])

# %%
data
# Out:
#            City      Date  AQI  PM2.5  PM10  NO2  SO2  CO  O3  AQI\t  PM2.5\t
# 0     Bangalore  01/01/18   68  37.40    40   40   40  40  40     40       40
# 1     Bangalore  02/01/18   76  41.80    48   48   48  48  48     48       48
# 2     Bangalore  03/01/18   70  38.50    42   42   42  42  42     42       42
# 3     Bangalore  04/01/18   78  42.90    50   50   50  50  50     50       50
# 4     Bangalore  05/01/18   82  45.10    54   54   54  54  54     54       54
# ...         ...       ...  ...    ...   ...  ...  ...  ..  ..    ...      ...
# 2551  Bangalore  27/12/24   54  29.70    26   26   26  26  26     26       26
# 2552  Bangalore  28/12/24   57  31.35    29   29   29  29  29     29       29
# 2553  Bangalore  29/12/24   70  38.50    42   42   42  42  42     42       42
# 2554  Bangalore  30/12/24   62  34.10    34   34   34  34  34     34       34
# 2555  Bangalore  31/12/24   65  35.75    37   37   37  37  37     37       37
#
# [2556 rows x 11 columns]

# %%
x=data[['PM2.5','PM10','NO2','SO2','CO','O3']]
y=data[['AQI']]
x
# Out:
#       PM2.5  PM10  NO2  SO2  CO  O3
# 0     37.40    40   40   40  40  40
# 1     41.80    48   48   48  48  48
# 2     38.50    42   42   42  42  42
# 3     42.90    50   50   50  50  50
# 4     45.10    54   54   54  54  54
# ...     ...   ...  ...  ...  ..  ..
# 2551  29.70    26   26   26  26  26
# 2552  31.35    29   29   29  29  29
# 2553  38.50    42   42   42  42  42
# 2554  34.10    34   34   34  34  34
# 2555  35.75    37   37   37  37  37
#
# [2556 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2)
x_test
# Out:
#       PM2.5  PM10  NO2  SO2  CO  O3
# 325   32.45    31   31   31  31  31
# 1913  34.65    35   35   35  35  35
# 867   29.70    26   26   26  26  26
# 1880  42.35    49   49   49  49  49
# 1643  43.45    51   51   51  51  51
# ...     ...   ...  ...  ...  ..  ..
# 2144  68.75    97   97   97  97  97
# 1138  47.30    58   58   58  58  58
# 1903  28.60    24   24   24  24  24
# 1786  25.85    19   19   19  19  19
# 1953  28.05    23   23   23  23  23
#
# [2044 rows x 6 columns]

# %%
import seaborn as sns
sns.histplot(data["AQI"])
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
from sklearn.linear_model import LinearRegression
le1=LinearRegression()
le1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = le1.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 1.0

# %%
le1.predict([[47.42,90,58,40,12,43]])
# Out:
# C:\Users\ATHIRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[86.21818182]])

# %%
le1.predict(x_test)
# Out:
# array([[59.],
#        [63.],
#        [54.],
#        ...,
#        [52.],
#        [47.],
#        [51.]], shape=(2044, 1))

# %%
from sklearn.tree import DecisionTreeRegressor
li = DecisionTreeRegressor()
li.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
li.predict([[47.42,90,58,40,12,43]])
# Out:
# C:\Users\ATHIRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([83.])

# %%
le1.predict(x_test)
# Out:
# array([[59.],
#        [63.],
#        [54.],
#        ...,
#        [52.],
#        [47.],
#        [51.]], shape=(2044, 1))

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# C:\Users\ATHIRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
rf.predict([[47.42,90,58,40,12,43]])
# Out:
# C:\Users\ATHIRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([78.31])

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
knn.predict([[47.42,90,58,40,12,43]])
# Out:
# C:\Users\ATHIRA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([[77.]])

# %%
import pickle
file=open('aqi.pkl','wb')
pickle.dump(le1,file)
file.close()
